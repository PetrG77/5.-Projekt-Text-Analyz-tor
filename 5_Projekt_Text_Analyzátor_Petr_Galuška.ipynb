# %% [markdown]
# <a href="https://colab.research.google.com/github/PetrG77/5.-Projekt-Text-Analyz-tor/blob/main/5_Projekt_Text_Analyz%C3%A1tor_Petr_Galu%C5%A1ka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TEXTS = ['''
Situated about 10 miles west of Kemmerer, 
Fossil Butte is a ruggedly impressive 
topographic feature that rises sharply 
some 1000 feet above Twin Creek Valley 
to an elevation of more than 7500 feet 
above sea level. The butte is located just 
north of US 30N and the Union Pacific Railroad, 
which traverse the valley. ''',

'''At the base of Fossil Butte are the bright 
red, purple, yellow and gray beds of the Wasatch 
Formation. Eroded portions of these horizontal 
beds slope gradually upward from the valley floor 
and steepen abruptly. Overlying them and extending 
to the top of the butte are the much steeper 
buff-to-white beds of the Green River Formation, 
which are about 300 feet thick.''',

'''The monument contains 8198 acres and protects 
a portion of the largest deposit of freshwater fish 
fossils in the world. The richest fossil fish deposits 
are found in multiple limestone layers, which lie some 
100 feet below the top of the butte. The fossils 
represent several varieties of perch, as well as 
other freshwater genera and herring similar to those 
in modern oceans. Other fish such as paddlefish, 
garpike and stingray are also present.'''
]


# jméno a heslo
overeni = {'bob' : '123', 'ann' : 'pass123', 'mike' : 'password123', 'liz' : 'pass123'}
jmeno = input('username: ')
heslo = input('password: ')

if overeni.get(jmeno) == (heslo):
  print('-' * 41)
  print('Welcome to the app, ', jmeno)
  print('We have ', len(TEXTS), 'texts to be analyzed.')
  print('-' * 41)

# číslo textu
  cislo = input('Enter a number btw. 1 and 3 to select: ')
  print('-' * 41)

  if cislo[0].isnumeric() and int(cislo[0]) <= len(TEXTS) :
    print('-' * 41)
    print('LEN|  OCCURENCES  |NR.')
    print('-' * 41)
    vybrane_cislo = int(cislo) - 1
    vypis = TEXTS[vybrane_cislo]

# Rozdělení zvoleného textu  
    rozdel_text = vypis.split()
    

# Délka vybraného textu
    delka_textu = len(rozdel_text)
    print('There are ', delka_textu, 'words in the selected text.')

# Vyčištění vybraného textu od (,.?!)
    ciste_slovo = []
    for word in rozdel_text:
      ciste_slovo.append(word.strip(',.!?'))

# Slova začínající na " Velké písmeno"
    prvni_velke = []
    for slovo in ciste_slovo:
      if slovo.istitle():
        prvni_velke.append(slovo)
    pocet_prvni_velke = len(prvni_velke)
    print('There are ', pocet_prvni_velke, 'titlecase words.')

# Slova, která mají " VŠECHNO VELKÉ"
    vsechno_velke = []
    for slovo in ciste_slovo:
      if slovo.isupper():
        vsechno_velke.append(slovo)
    pocet_vsechno_velke = len(vsechno_velke)
    print('There are ', pocet_vsechno_velke, 'uppercase words.')

# Slova která jsou "malým písmem"
    vsechno_male = []
    for slovo in ciste_slovo:
      if slovo.islower():
        vsechno_male.append(slovo)
    pocet_vsechno_male = len(vsechno_male)
    print('There are ', pocet_vsechno_male, ' lowercase words.')

# Počet "čísel a součet čísel"
    cisla = []
    for slovo in ciste_slovo:
      if slovo.isdigit():
        cisla.append(int(slovo))
    pocet_cisel = len(cisla)
    celkovy_pocet = (sum(cisla))
    print('There are ', pocet_cisel, ' numeric strings.')
    print('The sum of all the numbers, ', celkovy_pocet)
    print('-' * 41)
    print('LEN|  OCCURENCES  |NR.')
    print('-' * 41)

# Délka slova 1
    jedna = []
    for word in ciste_slovo:
      if len(word) == 1:
        jedna.append(word)
      pocet_jedna = len(jedna)
    print('  1|', '*' * pocet_jedna, '|', pocet_jedna)

# Délka dva 2
    dva = []
    for word in ciste_slovo:
      if len(word) == 2:
        dva.append(word)
      pocet_dva = len(dva)
    print('  2|', '*' * pocet_dva, '|', pocet_dva)

# Délka dva 3
    tri = []
    for word in ciste_slovo:
      if len(word) == 3:
        tri.append(word)
      pocet_tri = len(tri)
    print('  3|', '*' * pocet_tri, '|', pocet_tri)

# Délka dva 4
    ctyri = []
    for word in ciste_slovo:
      if len(word) == 4:
        ctyri.append(word)
      pocet_ctyri = len(ctyri)
    print('  4|', '*' * pocet_ctyri, '|', pocet_ctyri)

# Délka dva 5
    pet = []
    for word in ciste_slovo:
      if len(word) == 5:
        pet.append(word)
      pocet_pet = len(pet)
    print('  5|', '*' * pocet_pet, '|', pocet_pet)

# Délka dva 6
    sest = []
    for word in ciste_slovo:
      if len(word) == 6:
        sest.append(word)
      pocet_sest = len(sest)
    print('  6|', '*' * pocet_sest, '|', pocet_sest)

# Délka dva 7
    sedm = []
    for word in ciste_slovo:
      if len(word) == 7:
        sedm.append(word)
      pocet_sedm = len(sedm)
    print('  7|', '*' * pocet_sedm, '|', pocet_sedm)

# Délka dva 8
    osm = []
    for word in ciste_slovo:
      if len(word) == 8:
        osm.append(word)
      pocet_osm = len(osm)
    print('  8|', '*' * pocet_osm, '|', pocet_osm)

# Délka dva 9
    devet = []
    for word in ciste_slovo:
      if len(word) == 9:
        devet.append(word)
      pocet_devet = len(devet)
    print('  9|', '*' * pocet_devet, '|', pocet_devet)

# Délka dva 10
    deset = []
    for word in ciste_slovo:
      if len(word) == 10:
        deset.append(word)
      pocet_deset = len(deset)
    print(' 10|', '*' * pocet_deset, '|', pocet_deset)

# Délka dva 11
    jedenact = []
    for word in ciste_slovo:
      if len(word) == 11:
        jedenact.append(word)
      pocet_jedenact = len(jedenact)
    print(' 11|', '*' * pocet_jedenact, '|', pocet_jedenact)

# Délka dva 12
    dvanact = []
    for word in ciste_slovo:
      if len(word) == 12:
        dvanact.append(word)
      pocet_dvanact = len(dvanact)
    print(' 12|', '*' * pocet_dvanact, '|', pocet_dvanact)

# Délka dva 13
    trinact = []
    for word in ciste_slovo:
      if len(word) == 13:
        trinact.append(word)
      pocet_trinact = len(trinact)
    print(' 13|', '*' * pocet_trinact, '|', pocet_trinact)

# Délka dva 14
    ctrnact = []
    for word in ciste_slovo:
      if len(word) == 14:
        ctrnact.append(word)
      pocet_ctrnact = len(ctrnact)
    print(' 14|', '*' * pocet_ctrnact, '|', pocet_ctrnact)

# Délka dva 15
    patnact = []
    for word in ciste_slovo:
      if len(word) == 15:
        patnact.append(word)
      pocet_patnact = len(patnact)
    print(' 15|', '*' * pocet_patnact, '|', pocet_patnact)

    
  else:
    print('Sorry, you wrote : ' + '"' + cislo + '"')
    print('Enter a number btw. 1 -', len(TEXTS))
    print('The program will be terminated!')
    
        

else:
  print('The name or password is entered incorrectly. The program will be terminated!')
  exit()
# Out:
# username: bob
# password: 123
# -----------------------------------------
# Welcome to the app,  bob
# We have  3 texts to be analyzed.
# -----------------------------------------
# Enter a number btw. 1 and 3 to select: 1
# -----------------------------------------
# -----------------------------------------
# LEN|  OCCURENCES  |NR.
# -----------------------------------------
# There are  54 words in the selected text.
# There are  12 titlecase words.
# There are  2 uppercase words.
# There are  38  lowercase words.
# There are  3  numeric strings.
# The sum of all the numbers,  8510
# -----------------------------------------
# LEN|  OCCURENCES  |NR.
# -----------------------------------------
#   1| * | 1
#   2| ********* | 9
#   3| ****** | 6
#   4| *********** | 11
#   5| ************ | 12
#   6| *** | 3
#   7| **** | 4
#   8| ***** | 5
#   9| * | 1
#  10| * | 1
#  11| * | 1
#  12|  | 0
#  13|  | 0
#  14|  | 0
#  15|  | 0
